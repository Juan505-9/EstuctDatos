# %% [markdown]
# # Homework 1

# %% [markdown]
# ##  1. Sort the following functions in decreasing order of asymptotic complexity ($O(f(n))$):
#
# - $f_1(n) = n^\sqrt{n}$
# - $f_2(n) = 2^n$
# - $f_3(n) = {n\choose 2}$
# - $f_4(n) = \sum_{i=2}^n (i-1)$

# %% [markdown]
# ## 2. Implement in Python the insertion sort procedure to sort into non-increasing instead of non-decreasing order
#
# 1. Use the `time` function to measure the execution time for the best and worst inputs of size between 10 and 1,000 (use steps of 10)
# 2. Plot the best and worst execution times measured in (2.1) as a function of $n$
# 3. Use the `random` function to generate randomly sorted inputs to calculate the execution time. For each $n$ run the program for 100 different inputs. Do for $n = 100,200, \dots, 1000$.
# 4. Plot the mean, median, and standard deviation as a function of $n$ for the values obtained in 2.3

# %% [markdown]
# ## 3.  CLRS 2.1-4
# pg. 22

# %% [markdown]
# Consider the problem of adding two n-bit binary integers, stored in two n-element arrays A and B. The sum of the two integers should be stored in binary form in an $(n+1)$-element array C. State the problem formally and write the pseudocode for adding the two integrers

# %% [markdown]
# $A[n-1]\\$
# $B[n-1]$
# $C[n]$ Longitud de lo que va a ser la suma entre A y B y seran numeros binaros significa que sera 0 o 1
# $C=B+A$
#
# $C[n+1]$es el nuevo arreglo en el que se almacenara la suma

# %% [markdown]
# ## 4.  CLRS 3.1-1
# pg. 52

# %% [markdown]
# Let $f(n)$ and $g(n)$ be asymptotically nonnegative functions. Using the basic defi- nition of $\Theta$ notation, prove that max $(f(n), g(n)) = \Theta(f(n)+g(n))$

# %% [markdown]
# Para lograr probar esto debemos utilizar las constantes $c1,c2,n0>0$ para que $n>=n0$
#
# $0<=c1(f(n)+g(n))<=max(f(n),g(n))<=c2(f(n)+g(n))$
#
# Asumimos que $n0>0,f(n)>=0$ y$g(n)>=0$
#
# $f(n) +g(n) >= max(f(n),g(n))$
#
# $1/2(f(n)+g(n))<=max(f(n),g(n))$
#
# Entonces $max(f(n),g(n))=\Theta(f(n),g(n))$ porque hay el $c1=0.5$ y el $c2=1$

# %% [markdown]
# ## 5. CLRS 3.1-2
# pg. 52

# %% [markdown]
# Show that for any real constants a and b, where b > 0,
#
# $ (n+a)^b = \Theta(n^b)$

# %% [markdown]
# $n+a <= 4$
#
# $n+a >= n/2\newline$
#
# $0<=n/4<=n+a<=4a\newline$
#
# $0<=(n/4)^b<=(n+a)^b<=(4n)^b\newline$
#
# $0<=(1/4^b)*n^b<=(n+a)^b<=2^bn^b\newline$
#
# Entonces lo que ocurre es que $(n+a)^b =\theta (n^b)$ porque $c1 = 1/4^b , c2 = 4^b$

# %% [markdown]
# ## 6. CLRS 3.1-6
# pg. 53

# %% [markdown]
# Prove that the running time of an algorithm is $\Theta(g(n))$ if and only if its worst-case running time is O(g(n)) and its best-case running time is $\Omega(g(n))$

# %% [markdown]
# ## 7. CLRS 3-4 (a,b,e,g)
# pg. 62

# %% [markdown]
# $a. f(n)= O(g(n))$ implies $g(n)= O(f(n))$
#
# $b. f(n) + g(n) = \Theta(min(f(n),g(n)))$
#
# $e. f(n) = O((f(n)^2))$
#
# $g. f(n) = \Theta(f(n/2))$

# %% [markdown]
#  La A es FALSO porque si dejamos que $f(n) = n$ y $g(n)=n^2*n = O(n^2)$ pero $n^2 \neq O(n)$
#
#  La B es FALSO porque si $n^2 + n \neq\Theta(min(n^2,n))=\Theta (min(n))$
#
#  La E es FALSO porque si $n^2 + n \neq\Theta(min(n^2,n))=\Theta (min(n))$
#
#  La G es FALSO porque si dejamos que $f(n) =4^n * 4^n \neq \Theta (4^{n\2})  = \Theta (2^n)$
